# %%
import os
os.chdir('..')
import warnings
warnings.filterwarnings('ignore')

# %%
from scripts.telegram_scrapper import start_scraping

# %%
# Define the list of Telegram channels to scrape
channels = ['@ZemenExpress']

# Call the scraping function
start_scraping(channels, csv_file='telegram_data.csv', limit=100)
# Out:
# Scraping data from @ZemenExpress (Zemen Express®)...
# Extracting entities from message: 💥💥...................................💥💥
#
# 🎯Korean Body Scrub Sponge
#
#      👍የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ
#
# ዋጋ፦  💲🏷  200 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '200 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 🎯Korean Body Scrub Sponge
#      👍የሞተ ቆዳን እንዲሁም ቆሻሻን ለማፅዳት ተመራጭ
#
# ዋጋ፦  💲🏷  200 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '200 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥.............👡 👟................💥💥
#
# 🎯Stainless Steel Shoes Rack
# 🔰ከብረት የተሰራ
# 🔰ጫማ እና የተለያዩ ዕቃወች ማስቀመጫ
# 🔰ለመገጣጠም ቀላል
# 👟👠📙📃🗄️
# 💯 High Quality
#
# ባለ ስድስት መደርደሪያ ያለው
# ☑️ Size :- 55*26*114
#
#  ዋጋ፦  💵🏷  2250 ብር
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Simple Wardrobe
# ዘመናዊ የልብስ ማስቀመጫ ቁምሳጥን
#
# 👍በቀላሉ የሚገጣጠም የሚነቃቀል
# 👍ከቦታ ወደ ቦታ ለማንቀሳቀስ የሚመች
# 👍ቀላል ክብደት ያለው
# 👍ባለ ዚፕ የሸራ ልብስ ያለው
# 👍ፍሬሞቹ የብረት ቱቦዎች የሆኑ
# 👍መገጣጠሚያዎቹ ጠንካራ ካርቦኔትድ ፕላስቲኮች የሆኑ
# 👍ለቤትዎ ውበት የሚሠጥ
# 👍ቦታ የማይዝ ሲሆን
#
# 👍ቁመት 175 ሳ.ሜ
# 👍የጎን ስፋት 130 ሳ.ሜ
# 👍ወርድ 45 ሳ.ሜ
#
# ዋጋ፦  💰 🏷  3500 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '500 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Silicone Forefoot Soft Pads for Pain
#
# Note: If your gel cushions slip and bunch, try wearing snug fitting socks to help keep them in place.
#
# Specification:
# Colors: white
# Material: silicone gel
#
# ዋጋ፦  💰 🏷  150 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '150 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Folding Egg Rack
#
# 💯ከፍተኛ ጥራት
#
# 🛡እስከ 30 እንቁላል መያዝ የሚችል
# 🛡ፍሪጅዎን በስርአት ለመጠቀም ተመራጭ
# 🛡ለመኖሪያ ቤት እንዲሁም ለሬስቶራንት የሚሆን
#
# 🛡24 egg storage holder
# 🛡3 layer foldable egg organizer
# 🛡kitchen countertop portable egg carrier
#
# ዋጋ፦  💰 🏷  1,100 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '1,100 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Folding Egg Rack
#
# 💯ከፍተኛ ጥራት
#
# 🛡እስከ 30 እንቁላል መያዝ የሚችል
# 🛡ፍሪጅዎን በስርአት ለመጠቀም ተመራጭ
# 🛡ለመኖሪያ ቤት እንዲሁም ለሬስቶራንት የሚሆን
#
# 🛡24 egg storage holder
# 🛡3 layer foldable egg organizer
# 🛡kitchen countertop portable egg carrier
#
# ዋጋ፦  💰 🏷  1,100 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '1,100 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Automatic Rebound Healthy Abdomen Wheel
#
# 👍**Automatic Rebound Abdominal Wheel for Core Trainer Workout
# **👍 **Ab Workout Equipment with Elbow Support
# **👍**Home Abdominal Exercise Machine
# **👍**and Plank Roller in One**
#
# 👍  የቦርጭ ስብን ለማቅለጥ እና ፓክ ለማውጣት የሚመረጥ
# 👍 በቀላሉ የሆድ፣ የመቀመጫ፣ የጀርባ ጡንቻዎትን ለማሳሳብና ለማጠንከር ይረዳዎታል
# 👍 የራሱ መቁጠሪያ ሰዓት የተካተተለት
# 👍 በቀላሉ የተሸናቀጠ ተክለሰውነትን ይላበሱ
#
# ➡️Reliable & Durable
# ➡️Easy & Comfortable
# ➡️Easy to use
# ➡️Vast Application
# ➡️Excellent Gift Alternative
#
#  ዋጋ፦  💵🏷   2600 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '600 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Automatic Rebound Healthy Abdomen Wheel
#
# 👍**Automatic Rebound Abdominal Wheel for Core Trainer Workout
# **👍 **Ab Workout Equipment with Elbow Support
# **👍**Home Abdominal Exercise Machine
# **👍**and Plank Roller in One**
#
# 👍  የቦርጭ ስብን ለማቅለጥ እና ፓክ ለማውጣት የሚመረጥ
# 👍 በቀላሉ የሆድ፣ የመቀመጫ፣ የጀርባ ጡንቻዎትን ለማሳሳብና ለማጠንከር ይረዳዎታል
# 👍 የራሱ መቁጠሪያ ሰዓት የተካተተለት
# 👍 በቀላሉ የተሸናቀጠ ተክለሰውነትን ይላበሱ
#
# ➡️Reliable & Durable
# ➡️Easy & Comfortable
# ➡️Easy to use
# ➡️Vast Application
# ➡️Excellent Gift Alternative
#
#  ዋጋ፦  💵🏷   2600 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '600 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 Led Mirror Light
#
# 👍 ከሶኬት በተጨማሪ በባትሪ የሚሰራ
# 👍 የራሱ ማስደገፊያ ያለው
# 👍 ተንቀሳቃሽ
# 👍 3 የብርሀን ደረጃወች ያሉት
#
# ዋጋ፦  💵🏷  650 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '650 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 High pressure water Gun nozzle
#
#    👍መኪና ለማጠብ
#    👍ግቢ ለማፅዳት ተመራጭ
#    👍የራሱ መለዋወጫ ያለው
#
# ዋጋ፦  💵🏷  800 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '800 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 High pressure water Gun nozzle
#
#    👍መኪና ለማጠብ
#    👍ግቢ ለማፅዳት ተመራጭ
#    👍የራሱ መለዋወጫ ያለው
#
# ዋጋ፦  💵🏷  800 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '800 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 High pressure water Gun nozzle
#
#    👍መኪና ለማጠብ
#    👍ግቢ ለማፅዳት ተመራጭ
#    👍የራሱ መለዋወጫ ያለው
#
# ዋጋ፦  💵🏷  800 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '800 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 📌 Egg Poacher
#
# 👍ከ 1_ 14 እንቁላል መቀቀል የሚያስችል
# 👍በኤሌክትሪክ የሚሰራ
# 👍ለአጠቃም ቀላል እና ፈጣን
#
# ዋጋ፦  💲🏷 ትንሹ ➡️ 1000 ብር
#                      ትልቁ ➡️  1200 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '000 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...............👸................💥💥
#
# 📌Straight Comb Hair stylist
#
# ‼️ምንም አይነት ድምፅ የሌለው ‼️
#
# ሁሉንም አይነት ጸጉር ያለ ልፋት💯 በሙቀት የሚያስውብ
#
# 👍ለተለያዩ የጸጉር አይነቶች ከፍ እና ዝቅ የሚል የሙቀት መቆጣጠሪያ ያለው
#
# 👍ጸጉር ሳይሰባበር በጤናማ ሁኔታ ውብ የሚያደርግልዎ
#
# ዋጋ፦  💲🏷  1200ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '200ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...............👸................💥💥
#
# 📌Straight Comb Hair stylist
#
# ‼️ምንም አይነት ድምፅ የሌለው ‼️
#
# ሁሉንም አይነት ጸጉር ያለ ልፋት💯 በሙቀት የሚያስውብ
#
# 👍ለተለያዩ የጸጉር አይነቶች ከፍ እና ዝቅ የሚል የሙቀት መቆጣጠሪያ ያለው
#
# 👍ጸጉር ሳይሰባበር በጤናማ ሁኔታ ውብ የሚያደርግልዎ
#
# ዋጋ፦  💲🏷  1200ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '200ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...............👸................💥💥
#
# 📌Straight Comb Hair stylist
#
# ‼️ምንም አይነት ድምፅ የሌለው ‼️
#
# ሁሉንም አይነት ጸጉር ያለ ልፋት💯 በሙቀት የሚያስውብ
#
# 👍ለተለያዩ የጸጉር አይነቶች ከፍ እና ዝቅ የሚል የሙቀት መቆጣጠሪያ ያለው
#
# 👍ጸጉር ሳይሰባበር በጤናማ ሁኔታ ውብ የሚያደርግልዎ
#
# ዋጋ፦  💲🏷  1200ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '200ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 🎯 LCD Writing Tablet
#         ለልጅዎ
#
# 🖌Lcd writing tablet🖌
# (8.5inch)
#
# 👍ልጆች እየተዝናኑ የሚማሩበት
# LCD WRITING TAB
# 👍ለፅሁፍ እና ለስዕል መለማመጃ የሚሆን
# 👍የወረቀት እና እርሳስ ወጪን የሚቆጥብ
# 👍ብናኝ ወይም አይን የሚወጋ ብርሀን ስለሌለው በምቾት እና በደህንነት ለረጅም ሰአት የሚጠቀሙበት
# 👍ለቢሮ እና ለምግብ ቤት ለተለያዬ አገልግሎቶች መጠቀም ይችላሉ
# 👍ምስሉ የፈለጉትን ያህል መቆየት የሚችል ሲሆን አንድ ቁልፍ ብቻ በመጫን መቆለፍም ሆነ መሰረዝ ያስችላል ታብሌቱ ቀጭን ስለሆነ በእጅ ቦርሳ ለመያዝ አመቺ ነው።
#
# ዋጋ፦  💲🏷  500 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '500 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 🎯 LCD Writing Tablet
#         ለልጅዎ
#
# 🖌Lcd writing tablet🖌
# (8.5inch)
#
# 👍ልጆች እየተዝናኑ የሚማሩበት
# LCD WRITING TAB
# 👍ለፅሁፍ እና ለስዕል መለማመጃ የሚሆን
# 👍የወረቀት እና እርሳስ ወጪን የሚቆጥብ
# 👍ብናኝ ወይም አይን የሚወጋ ብርሀን ስለሌለው በምቾት እና በደህንነት ለረጅም ሰአት የሚጠቀሙበት
# 👍ለቢሮ እና ለምግብ ቤት ለተለያዬ አገልግሎቶች መጠቀም ይችላሉ
# 👍ምስሉ የፈለጉትን ያህል መቆየት የሚችል ሲሆን አንድ ቁልፍ ብቻ በመጫን መቆለፍም ሆነ መሰረዝ ያስችላል ታብሌቱ ቀጭን ስለሆነ በእጅ ቦርሳ ለመያዝ አመቺ ነው።
#
# ዋጋ፦  💲🏷  500 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '500 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 🎯 LCD Writing Tablet
#         ለልጅዎ
#
# 🖌Lcd writing tablet🖌
# (8.5inch)
#
# 👍ልጆች እየተዝናኑ የሚማሩበት
# LCD WRITING TAB
# 👍ለፅሁፍ እና ለስዕል መለማመጃ የሚሆን
# 👍የወረቀት እና እርሳስ ወጪን የሚቆጥብ
# 👍ብናኝ ወይም አይን የሚወጋ ብርሀን ስለሌለው በምቾት እና በደህንነት ለረጅም ሰአት የሚጠቀሙበት
# 👍ለቢሮ እና ለምግብ ቤት ለተለያዬ አገልግሎቶች መጠቀም ይችላሉ
# 👍ምስሉ የፈለጉትን ያህል መቆየት የሚችል ሲሆን አንድ ቁልፍ ብቻ በመጫን መቆለፍም ሆነ መሰረዝ ያስችላል ታብሌቱ ቀጭን ስለሆነ በእጅ ቦርሳ ለመያዝ አመቺ ነው።
#
# ዋጋ፦  💲🏷  500 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '500 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...............🌞.................💥💥
#
# ❓ በረፍት ቀንዎ ሱቅ ላይ መስተናገድ ለምትፈልጉ ውድ ደንበኞቻችን
#
#
# 🌐ነገ ከጠዋቱ 4:30 _ ቀኑ 11:00 ድረስ🌐
#           ሱቃችን ክፍት ሁኖ ይጠብቅዎታል
#
#
# 🟢 🚛 ሱቅ መተው መግዛት ላልቻላችሁ በሞተረኞች ያሉበት እናደርሳለን
#
# ⚠️ ዘወትር ሰኞ _ቅዳሜ ከጠዋቱ 2:30 እስከ ምሽቱ 2:00 ድረስ ክፍት መሆኑን እንገልፃለን
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '[No Price]', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Hair Scalp Massager
#
# ⚠️Silicone Bristles
#
#
# ዋጋ፦  💵🏷  250 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Hair Scalp Massager
#
# ⚠️Silicone Bristles
#
#
# ዋጋ፦  💵🏷  250 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌**Silicone Thumb Cutter**
#
# 🔼የጣት ጥፍር መከላከያ
# 🔼ሽንኩርት ሲልጡ ፣ ዝንጅብል እና በርበሬ
#      ዘለላ ሲቀነጥሱ ጥፍርን ከጉዳት የሚከላከል
# 🔼Material: Stainless Steel, Silicone, pp
# 🔼colour 🟠
#
#  ዋጋ፦  💵🏷  250 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌**Silicone Thumb Cutter**
#
# 🔼የጣት ጥፍር መከላከያ
# 🔼ሽንኩርት ሲልጡ ፣ ዝንጅብል እና በርበሬ
#      ዘለላ ሲቀነጥሱ ጥፍርን ከጉዳት የሚከላከል
# 🔼Material: Stainless Steel, Silicone, pp
# 🔼colour 🟠
#
#  ዋጋ፦  💵🏷  250 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# Only Baby
# 📌Food Feeder Plus
#
# 👍 100% Food Grade Silicone
# 👍 BPA Free
# 👍 Latex Free
# 👍 Phthalate Free
# 👍 Non- Toxic
# 👍 Freeze Safe
# 👍 Microwave Safe
# 👍 Boil Safe
# 👍Steam Safe
# 👍 Zero Month and Above
#
# ዋጋ፦  💲🏷  250 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# Only Baby
# 📌Food Feeder Plus
#
# 👍 100% Food Grade Silicone
# 👍 BPA Free
# 👍 Latex Free
# 👍 Phthalate Free
# 👍 Non- Toxic
# 👍 Freeze Safe
# 👍 Microwave Safe
# 👍 Boil Safe
# 👍Steam Safe
# 👍 Zero Month and Above
#
# ዋጋ፦  💲🏷  250 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 **Flame Aroma Diffuser Humidifier**
#        `💯 High Quality `
#
# 👍**በኤሌክትሪክ የሚሰራ
# ****👍**** ለቤት መልካም መዓዛን የሚሰጥ**
#
# `🚩Capacity: 200ml
# 🚩Purify the air & Beautify the Environment`
#
#
# 🔥__very effective: Usb power interface, convenient and quick operation, can be used anywhere.__
#
# ዋጋ፦  💲🏷  1400 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '400 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 **Flame Aroma Diffuser Humidifier**
#        `💯 High Quality `
#
# 👍**በኤሌክትሪክ የሚሰራ
# ****👍**** ለቤት መልካም መዓዛን የሚሰጥ**
#
# `🚩Capacity: 200ml
# 🚩Purify the air & Beautify the Environment`
#
#
# 🔥__very effective: Usb power interface, convenient and quick operation, can be used anywhere.__
#
# ዋጋ፦  💲🏷  1400 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '400 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 **Flame Aroma Diffuser Humidifier**
#        `💯 High Quality `
#
# 👍**በኤሌክትሪክ የሚሰራ
# ****👍**** ለቤት መልካም መዓዛን የሚሰጥ**
#
# `🚩Capacity: 200ml
# 🚩Purify the air & Beautify the Environment`
#
#
# 🔥__very effective: Usb power interface, convenient and quick operation, can be used anywhere.__
#
# ዋጋ፦  💲🏷  1400 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '400 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Lint remover /Fabric shaver for clothes
#
# 👍በቻርጅ የሚሰራ
#
# ዋጋ፦  💲🏷  900ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '900ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Lint remover /Fabric shaver for clothes
#
# 👍በቻርጅ የሚሰራ
#
# ዋጋ፦  💲🏷  900ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '900ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Lint remover /Fabric shaver for clothes
#
# 👍በቻርጅ የሚሰራ
#
# ዋጋ፦  💲🏷  900ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '900ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Rechargeable Electric Foot Callus Remover Kit
#
# ✔️ - Professional Pedicure Tool with USB Charging,
# ✔️Oil-Free,
# ✔️4-12V Power, Lithium Battery -
# ✔️Ideal for Dry, Cracked Skin Care
#
# ዋጋ፦  💵🏷  850 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '850 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Rechargeable Electric Foot Callus Remover Kit
#
# ✔️ - Professional Pedicure Tool with USB Charging,
# ✔️Oil-Free,
# ✔️4-12V Power, Lithium Battery -
# ✔️Ideal for Dry, Cracked Skin Care
#
# ዋጋ፦  💵🏷  850 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '850 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Rechargeable Electric Foot Callus Remover Kit
#
# ✔️ - Professional Pedicure Tool with USB Charging,
# ✔️Oil-Free,
# ✔️4-12V Power, Lithium Battery -
# ✔️Ideal for Dry, Cracked Skin Care
#
# ዋጋ፦  💵🏷  850 ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '850 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Natural Wood Twist Hexagon Led Desk lamp
#
# ✔️It is modern design
# ✔️** Portable USB Rechargeable Lamp,
# ****✔️**** Battery Powered Folding Ambient Night Light,
# ****✔️****Paper Lamp for Bedroom, Travel, Hotel, Restaurant, Living Room**
#
# ⚠️ ለአያያዝ በጣም ቀላል
#
# ዋጋ፦  💲🏷  1400 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '400 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌Natural Wood Twist Hexagon Led Desk lamp
#
# ✔️It is modern design
# ✔️** Portable USB Rechargeable Lamp,
# ****✔️**** Battery Powered Folding Ambient Night Light,
# ****✔️****Paper Lamp for Bedroom, Travel, Hotel, Restaurant, Living Room**
#
# ⚠️ ለአያያዝ በጣም ቀላል
#
# ዋጋ፦  💲🏷  1400 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '400 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌tripod stand
#
# 👍ሲዘረጋ 68cm
# 👍ሲሰበሰብ 18.5cm
#
# 👍selfie stick with remote
# 👍compatible with✅android ✅ios
#
# ⚠️Specifications :
#
#   👍main material:stainless steel
#   👍mount holder:2.4-3.8inch
#   👍retracted length 7inch/18.5cm
#   👍extended length 68cm
#
# ዋጋ፦  💲🏷  1200 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '200 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Coffee Cold Extraction Cup
#
# 👍Ice Coffee Maker
# 👍Portable Cold Brew Bottle Maker Mug
# 👍Leak Proof Airtight Lid with Mesh Filter
# ✨Ice Coffee Jar Tea Infuser for Outdoor
#
# ⚠️የአጠቃቀም ዘዴ
#
# 1️⃣,ለቡና ዱቄት የሚሆን በቂ ቦታ በመተው በውሃ መሙላት ይጀምሩ
#
# 2️⃣,ውስጥ ባለው ማጣሪያ የሚፈልጉትን የቡና መጠን ይጨምሩ
#
# 3️⃣,የማጣሪያውን ክዳን አጥብቀው ይዝጉ እና የቡናውን ቦታ በእኩል መጠን ለማከፋፈል ቀስ ብለው ማወዛወዝ
#
# 4️⃣,ለተወሰኑ ሰአታት ፍሪጅ ውስጥ ማስቀመጥ
#
# 5️⃣, ቀዝቃዛ ቡናዎን በበረዶ  ወይም ከወተት ጋር በመቀላቀል መጠጣት ይችላሉ
#
# ዋጋ፦  💲🏷  900 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '900 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Coffee Cold Extraction Cup
#
# 👍Ice Coffee Maker
# 👍Portable Cold Brew Bottle Maker Mug
# 👍Leak Proof Airtight Lid with Mesh Filter
# ✨Ice Coffee Jar Tea Infuser for Outdoor
#
# ⚠️የአጠቃቀም ዘዴ
#
# 1️⃣,ለቡና ዱቄት የሚሆን በቂ ቦታ በመተው በውሃ መሙላት ይጀምሩ
#
# 2️⃣,ውስጥ ባለው ማጣሪያ የሚፈልጉትን የቡና መጠን ይጨምሩ
#
# 3️⃣,የማጣሪያውን ክዳን አጥብቀው ይዝጉ እና የቡናውን ቦታ በእኩል መጠን ለማከፋፈል ቀስ ብለው ማወዛወዝ
#
# 4️⃣,ለተወሰኑ ሰአታት ፍሪጅ ውስጥ ማስቀመጥ
#
# 5️⃣, ቀዝቃዛ ቡናዎን በበረዶ  ወይም ከወተት ጋር በመቀላቀል መጠጣት ይችላሉ
#
# ዋጋ፦  💲🏷  900 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '900 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌Stainless steel baking bread pan
#
# ዋጋ፦  💲🏷  450 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '450 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌1 pair Silicone Gel Moisturizing Socks
#
# ⚠️ Pedicure Socks For
#
# 👍 Repairing Dry Feet cracked heel and
# 👍Softening Rough skin heated foot bath
#
# ዋጋ፦  💲🏷  400 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '400 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌1 pair Silicone Gel Moisturizing Socks
#
# ⚠️ Pedicure Socks For
#
# 👍 Repairing Dry Feet cracked heel and
# 👍Softening Rough skin heated foot bath
#
# ዋጋ፦  💲🏷  400 ብር ✅
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '400 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: 💥💥....................................💥💥
#
# 📌 Measuring Cup & Spoon Set
#
# ዋጋ፦  💲🏷  4pc ➡️250 ብር
#
# ♦️ውስን ፍሬ ነው ያለው🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '250 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: [No Text]
# Extracted entities: {'price': '[No Price]', 'phones': '[No Phone Numbers]', 'address': '[No Address]'}
# Extracting entities from message: 💥💥...................................💥💥
#
# 📌 6pcs Reusable drinking Stainless Straws with Cleaning brush
#
# 👍እንደ ማማሰያም መጠጫም የሚያገለግል
# 👍የማይዝግ
# 👍የራሱ ማፅጃ ብሩሽ ያለው
# 👍 በ 2 የቀለም አማራጭ Gold & Silver
#
#  ዋጋ፦  💵🏷  600 ብር
#
#
# ♦️ውስን ፍሬ ነው ያለው 😀😀😀
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# ➡️ 🔴ፒያሳ ቅርንጫፍ 0941337070
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
# Extracted entities: {'price': '600 ብር', 'phones': '0902660722, 0928460606, 0941337070', 'address': 'ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06\nቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107'}
# Finished scraping @ZemenExpress
